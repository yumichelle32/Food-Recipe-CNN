# %% [markdown]
# # [Chefkoch.de](http://www.chefkoch.de/) Maturaarbeit 2017/18
# ------
#
# ## Ziel:
# ### Dimensionsreduzierung mit LDA und t-SNE mit besserer Hardware (4.Teil, Part 2)

# %% [markdown]
# # Need a new and clean env, different from 04_01 env

# %%
# !pip install markupsafe==2.0.1
# !pip install psutil
# !pip install lda
# !pip install bokeh
# Out:
# Requirement already satisfied: markupsafe==2.0.1 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (2.0.1)
# Requirement already satisfied: psutil in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (5.9.0)
# Requirement already satisfied: lda in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (2.0.0)
# Requirement already satisfied: pbr<4,>=0.6 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from lda) (3.1.1)
# Requirement already satisfied: numpy<2.0,>=1.13.0 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from lda) (1.23.3)
# Requirement already satisfied: bokeh in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (3.0.3)
# Requirement already satisfied: pillow>=7.1.0 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from bokeh) (9.2.0)
# Requirement already satisfied: PyYAML>=3.10 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from bokeh) (6.0)
# Requirement already satisfied: numpy>=1.11.3 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from bokeh) (1.23.3)
# Requirement already satisfied: packaging>=16.8 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from bokeh) (21.3)
# Requirement already satisfied: tornado>=5.1 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from bokeh) (6.2)
# Requirement already satisfied: contourpy>=1 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from bokeh) (1.0.6)
# Requirement already satisfied: Jinja2>=2.9 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from bokeh) (2.11.3)
# Requirement already satisfied: pandas>=1.2 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from bokeh) (1.5.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from bokeh) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.9->bokeh) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from packaging>=16.8->bokeh) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.2->bokeh) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.2->bokeh) (1.16.0)

# %%
import csv

from gensim import corpora, models
import gensim

# %%
def get_recipe_names():
    recipe_names = []
    skip_first = True # col name
    chef_file = 'input/test/chefkoch_rezepte_analysis_cleannames.csv'
    with open(chef_file, 'r') as f:
        chefkoch = csv.reader(f)
        for row in chefkoch:
            if skip_first:
                skip_first = False
                continue
            try:
                recipe_names.append(row[-1])
            except: 
                continue 
    return(recipe_names)

# %%
recipe_names = get_recipe_names()
print(len(recipe_names)) # Anzahl aller Rezeptnamen
# Out:
# 316755

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import os
import argparse
import time
import lda
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import bokeh.plotting as bp
from bokeh.plotting import save
from bokeh.models import HoverTool

# %%
out_dir = "output_tsne"
os.makedirs(out_dir, exist_ok=True)

# %%
# unpack
n_topics = 40
n_iter = 500
n_top_words = 4
threshold = 0

##############################################################################
# train an LDA model

cvectorizer = CountVectorizer(min_df=1)
cvz = cvectorizer.fit_transform(recipe_names)

lda_model = lda.LDA(n_topics=n_topics, n_iter=n_iter)
X_topics = lda_model.fit_transform(cvz)


np.save(out_dir +'/lda_doc_topic_{}recipe_names{}topics_cloud_2.npy'.format(X_topics.shape[0], X_topics.shape[1]), X_topics)

np.save(out_dir +'/lda_topic_word_{}recipe_names{}topics_cloud_2.npy'.format(X_topics.shape[0], X_topics.shape[1]), lda_model.topic_word_)

print('\n>>> doc_topic & topic word written to disk\n')
# Out:
# 2022-12-09 21:36:59,480 : INFO : n_documents: 316755
# 2022-12-09 21:36:59,480 : INFO : vocab_size: 60479
# 2022-12-09 21:36:59,480 : INFO : n_words: 571982
# 2022-12-09 21:36:59,481 : INFO : n_topics: 40
# 2022-12-09 21:36:59,481 : INFO : n_iter: 500
# 2022-12-09 21:37:04,320 : INFO : <0> log likelihood: -7597635
# 2022-12-09 21:37:05,219 : INFO : <10> log likelihood: -6148883
# 2022-12-09 21:37:06,147 : INFO : <20> log likelihood: -5751467
# 2022-12-09 21:37:07,078 : INFO : <30> log likelihood: -5593311
# 2022-12-09 21:37:07,993 : INFO : <40> log likelihood: -5526442
# 2022-12-09 21:37:08,885 : INFO : <50> log likelihood: -5490208
# 2022-12-09 21:37:09,802 : INFO : <60> log likelihood: -5463076
# 2022-12-09 21:37:10,683 : INFO : <70> log likelihood: -5446041
# 2022-12-09 21:37:11,544 : INFO : <80> log likelihood: -5435027
# 2022-12-09 21:37:12,476 : INFO : <90> log likelihood: -5419944
# 2022-12-09 21:37:13,391 : INFO : <100> log likelihood: -5410059
# 2022-12-09 21:37:14,277 : INFO : <110> log likelihood: -5400389
# 2022-12-09 21:37:15,196 : INFO : <120> log likelihood: -5390561
# 2022-12-09 21:37:16,089 : INFO : <130> log likelihood: -5385740
# 2022-12-09 21:37:16,970 : INFO : <140> log likelihood: -5379328
# 2022-12-09 21:37:17,856 : INFO : <150> log likelihood: -5373704
# 2022-12-09 21:37:18,736 : INFO : <160> log likelihood: -5372484
# 2022-12-09 21:37:19,631 : INFO : <170> log likelihood: -5367429
# 2022-12-09 21:37:20,523 : INFO : <180> log likelihood: -5361557
# 2022-12-09 21:37:21,410 : INFO : <190> log likelihood: -5359342
# 2022-12-09 21:37:22,271 : INFO : <200> log likelihood: -5358637
# 2022-12-09 21:37:23,144 : INFO : <210> log likelihood: -5357705
# 2022-12-09 21:37:24,026 : INFO : <220> log likelihood: -5355063
# 2022-12-09 21:37:24,902 : INFO : <230> log likelihood: -5351771
# 2022-12-09 21:37:25,795 : INFO : <240> log likelihood: -5351259
# 2022-12-09 21:37:26,665 : INFO : <250> log likelihood: -5351298
# 2022-12-09 21:37:27,531 : INFO : <260> log likelihood: -5351834
# 2022-12-09 21:37:28,426 : INFO : <270> log likelihood: -5347512
# 2022-12-09 21:37:29,310 : INFO : <280> log likelihood: -5347384
# 2022-12-09 21:37:30,197 : INFO : <290> log likelihood: -5345720
# 2022-12-09 21:37:31,060 : INFO : <300> log likelihood: -5345391
# 2022-12-09 21:37:31,969 : INFO : <310> log likelihood: -5345065
# 2022-12-09 21:37:32,882 : INFO : <320> log likelihood: -5342004
# 2022-12-09 21:37:33,824 : INFO : <330> log likelihood: -5340773
# 2022-12-09 21:37:34,729 : INFO : <340> log likelihood: -5341437
# 2022-12-09 21:37:35,651 : INFO : <350> log likelihood: -5341184
# 2022-12-09 21:37:36,568 : INFO : <360> log likelihood: -5342042
# 2022-12-09 21:37:37,501 : INFO : <370> log likelihood: -5339646
# 2022-12-09 21:37:38,384 : INFO : <380> log likelihood: -5338861
# 2022-12-09 21:37:39,289 : INFO : <390> log likelihood: -5340206
# 2022-12-09 21:37:40,167 : INFO : <400> log likelihood: -5339441
# 2022-12-09 21:37:41,047 : INFO : <410> log likelihood: -5338626
# 2022-12-09 21:37:41,917 : INFO : <420> log likelihood: -5339006
# 2022-12-09 21:37:42,778 : INFO : <430> log likelihood: -5337891
# 2022-12-09 21:37:43,636 : INFO : <440> log likelihood: -5337116
# 2022-12-09 21:37:44,538 : INFO : <450> log likelihood: -5339339
# 2022-12-09 21:37:45,478 : INFO : <460> log likelihood: -5339079
# 2022-12-09 21:37:46,383 : INFO : <470> log likelihood: -5335262
# 2022-12-09 21:37:47,258 : INFO : <480> log likelihood: -5337778
# 2022-12-09 21:37:48,142 : INFO : <490> log likelihood: -5337955
# 2022-12-09 21:37:49,013 : INFO : <499> log likelihood: -5335748
# >>> doc_topic & topic word written to disk

# %%
##############################################################################
# threshold and plot

_idx = np.amax(X_topics, axis=1) > threshold  # idx of recipe_names that > threshold
_topics = X_topics[_idx]

num_example = len(_topics)

# %%
num_example
# Out:
# 316755

# %%
import psutil
psutil.virtual_memory()
# Out:
# svmem(total=17179869184, available=933187584, percent=94.6, used=1593573376, free=15572992, active=919846912, inactive=887349248, wired=673726464)

# %%
import joblib

# %%
# t-SNE: 50 -> 2D
tsne_model = TSNE(n_components=2, perplexity=5, verbose=2, random_state=0, angle=.7, learning_rate=150,
                    init='pca', n_iter=2500, n_iter_without_progress=100)
tsne_lda = tsne_model.fit_transform(_topics[:num_example])

# save tsne model
joblib.dump(tsne_lda, out_dir+'/tsne_lda_cloud_2.pkl')
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 316755 samples in 0.004s...
# [t-SNE] Computed neighbors for 316755 samples in 89.581s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 316755
# [t-SNE] Computed conditional probabilities for sample 2000 / 316755
# [t-SNE] Computed conditional probabilities for sample 3000 / 316755
# [t-SNE] Computed conditional probabilities for sample 4000 / 316755
# [t-SNE] Computed conditional probabilities for sample 5000 / 316755
# [t-SNE] Computed conditional probabilities for sample 6000 / 316755
# [t-SNE] Computed conditional probabilities for sample 7000 / 316755
# [t-SNE] Computed conditional probabilities for sample 8000 / 316755
# [t-SNE] Computed conditional probabilities for sample 9000 / 316755
# [t-SNE] Computed conditional probabilities for sample 10000 / 316755
# [t-SNE] Computed conditional probabilities for sample 11000 / 316755
# [t-SNE] Computed conditional probabilities for sample 12000 / 316755
# [t-SNE] Computed conditional probabilities for sample 13000 / 316755
# [t-SNE] Computed conditional probabilities for sample 14000 / 316755
# [t-SNE] Computed conditional probabilities for sample 15000 / 316755
# [t-SNE] Computed conditional probabilities for sample 16000 / 316755
# [t-SNE] Computed conditional probabilities for sample 17000 / 316755
# [t-SNE] Computed conditional probabilities for sample 18000 / 316755
# [t-SNE] Computed conditional probabilities for sample 19000 / 316755
# [t-SNE] Computed conditional probabilities for sample 20000 / 316755
# [t-SNE] Computed conditional probabilities for sample 21000 / 316755
# [t-SNE] Computed conditional probabilities for sample 22000 / 316755
# [t-SNE] Computed conditional probabilities for sample 23000 / 316755
# [t-SNE] Computed conditional probabilities for sample 24000 / 316755
# [t-SNE] Computed conditional probabilities for sample 25000 / 316755
# [t-SNE] Computed conditional probabilities for sample 26000 / 316755
# [t-SNE] Computed conditional probabilities for sample 27000 / 316755
# [t-SNE] Computed conditional probabilities for sample 28000 / 316755
# [t-SNE] Computed conditional probabilities for sample 29000 / 316755
# [t-SNE] Computed conditional probabilities for sample 30000 / 316755
# [t-SNE] Computed conditional probabilities for sample 31000 / 316755
# [t-SNE] Computed conditional probabilities for sample 32000 / 316755
# [t-SNE] Computed conditional probabilities for sample 33000 / 316755
# [t-SNE] Computed conditional probabilities for sample 34000 / 316755
# [t-SNE] Computed conditional probabilities for sample 35000 / 316755
# [t-SNE] Computed conditional probabilities for sample 36000 / 316755
# [t-SNE] Computed conditional probabilities for sample 37000 / 316755
# [t-SNE] Computed conditional probabilities for sample 38000 / 316755
# [t-SNE] Computed conditional probabilities for sample 39000 / 316755
# [t-SNE] Computed conditional probabilities for sample 40000 / 316755
# [t-SNE] Computed conditional probabilities for sample 41000 / 316755
# [t-SNE] Computed conditional probabilities for sample 42000 / 316755
# [t-SNE] Computed conditional probabilities for sample 43000 / 316755
# [t-SNE] Computed conditional probabilities for sample 44000 / 316755
# [t-SNE] Computed conditional probabilities for sample 45000 / 316755
# [t-SNE] Computed conditional probabilities for sample 46000 / 316755
# [t-SNE] Computed conditional probabilities for sample 47000 / 316755
# [t-SNE] Computed conditional probabilities for sample 48000 / 316755
# [t-SNE] Computed conditional probabilities for sample 49000 / 316755
# [t-SNE] Computed conditional probabilities for sample 50000 / 316755
# [t-SNE] Computed conditional probabilities for sample 51000 / 316755
# [t-SNE] Computed conditional probabilities for sample 52000 / 316755
# [t-SNE] Computed conditional probabilities for sample 53000 / 316755
# [t-SNE] Computed conditional probabilities for sample 54000 / 316755
# [t-SNE] Computed conditional probabilities for sample 55000 / 316755
# [t-SNE] Computed conditional probabilities for sample 56000 / 316755
# [t-SNE] Computed conditional probabilities for sample 57000 / 316755
# [t-SNE] Computed conditional probabilities for sample 58000 / 316755
# [t-SNE] Computed conditional probabilities for sample 59000 / 316755
# [t-SNE] Computed conditional probabilities for sample 60000 / 316755
# [t-SNE] Computed conditional probabilities for sample 61000 / 316755
# [t-SNE] Computed conditional probabilities for sample 62000 / 316755
# [t-SNE] Computed conditional probabilities for sample 63000 / 316755
# [t-SNE] Computed conditional probabilities for sample 64000 / 316755
# [t-SNE] Computed conditional probabilities for sample 65000 / 316755
# [t-SNE] Computed conditional probabilities for sample 66000 / 316755
# [t-SNE] Computed conditional probabilities for sample 67000 / 316755
# [t-SNE] Computed conditional probabilities for sample 68000 / 316755
# [t-SNE] Computed conditional probabilities for sample 69000 / 316755
# [t-SNE] Computed conditional probabilities for sample 70000 / 316755
# [t-SNE] Computed conditional probabilities for sample 71000 / 316755
# [t-SNE] Computed conditional probabilities for sample 72000 / 316755
# [t-SNE] Computed conditional probabilities for sample 73000 / 316755
# [t-SNE] Computed conditional probabilities for sample 74000 / 316755
# [t-SNE] Computed conditional probabilities for sample 75000 / 316755
# [t-SNE] Computed conditional probabilities for sample 76000 / 316755
# [t-SNE] Computed conditional probabilities for sample 77000 / 316755
# [t-SNE] Computed conditional probabilities for sample 78000 / 316755
# [t-SNE] Computed conditional probabilities for sample 79000 / 316755
# [t-SNE] Computed conditional probabilities for sample 80000 / 316755
# [t-SNE] Computed conditional probabilities for sample 81000 / 316755
# [t-SNE] Computed conditional probabilities for sample 82000 / 316755
# [t-SNE] Computed conditional probabilities for sample 83000 / 316755
# [t-SNE] Computed conditional probabilities for sample 84000 / 316755
# [t-SNE] Computed conditional probabilities for sample 85000 / 316755
# [t-SNE] Computed conditional probabilities for sample 86000 / 316755
# [t-SNE] Computed conditional probabilities for sample 87000 / 316755
# [t-SNE] Computed conditional probabilities for sample 88000 / 316755
# [t-SNE] Computed conditional probabilities for sample 89000 / 316755
# [t-SNE] Computed conditional probabilities for sample 90000 / 316755
# [t-SNE] Computed conditional probabilities for sample 91000 / 316755
# [t-SNE] Computed conditional probabilities for sample 92000 / 316755
# [t-SNE] Computed conditional probabilities for sample 93000 / 316755
# [t-SNE] Computed conditional probabilities for sample 94000 / 316755
# [t-SNE] Computed conditional probabilities for sample 95000 / 316755
# [t-SNE] Computed conditional probabilities for sample 96000 / 316755
# [t-SNE] Computed conditional probabilities for sample 97000 / 316755
# [t-SNE] Computed conditional probabilities for sample 98000 / 316755
# [t-SNE] Computed conditional probabilities for sample 99000 / 316755
# [t-SNE] Computed conditional probabilities for sample 100000 / 316755
# [t-SNE] Computed conditional probabilities for sample 101000 / 316755
# [t-SNE] Computed conditional probabilities for sample 102000 / 316755
# [t-SNE] Computed conditional probabilities for sample 103000 / 316755
# [t-SNE] Computed conditional probabilities for sample 104000 / 316755
# [t-SNE] Computed conditional probabilities for sample 105000 / 316755
# [t-SNE] Computed conditional probabilities for sample 106000 / 316755
# [t-SNE] Computed conditional probabilities for sample 107000 / 316755
# [t-SNE] Computed conditional probabilities for sample 108000 / 316755
# [t-SNE] Computed conditional probabilities for sample 109000 / 316755
# [t-SNE] Computed conditional probabilities for sample 110000 / 316755
# [t-SNE] Computed conditional probabilities for sample 111000 / 316755
# [t-SNE] Computed conditional probabilities for sample 112000 / 316755
# [t-SNE] Computed conditional probabilities for sample 113000 / 316755
# [t-SNE] Computed conditional probabilities for sample 114000 / 316755
# [t-SNE] Computed conditional probabilities for sample 115000 / 316755
# [t-SNE] Computed conditional probabilities for sample 116000 / 316755
# [t-SNE] Computed conditional probabilities for sample 117000 / 316755
# [t-SNE] Computed conditional probabilities for sample 118000 / 316755
# [t-SNE] Computed conditional probabilities for sample 119000 / 316755
# [t-SNE] Computed conditional probabilities for sample 120000 / 316755
# [t-SNE] Computed conditional probabilities for sample 121000 / 316755
# [t-SNE] Computed conditional probabilities for sample 122000 / 316755
# [t-SNE] Computed conditional probabilities for sample 123000 / 316755
# [t-SNE] Computed conditional probabilities for sample 124000 / 316755
# [t-SNE] Computed conditional probabilities for sample 125000 / 316755
# [t-SNE] Computed conditional probabilities for sample 126000 / 316755
# [t-SNE] Computed conditional probabilities for sample 127000 / 316755
# [t-SNE] Computed conditional probabilities for sample 128000 / 316755
# [t-SNE] Computed conditional probabilities for sample 129000 / 316755
# [t-SNE] Computed conditional probabilities for sample 130000 / 316755
# [t-SNE] Computed conditional probabilities for sample 131000 / 316755
# [t-SNE] Computed conditional probabilities for sample 132000 / 316755
# [t-SNE] Computed conditional probabilities for sample 133000 / 316755
# [t-SNE] Computed conditional probabilities for sample 134000 / 316755
# [t-SNE] Computed conditional probabilities for sample 135000 / 316755
# [t-SNE] Computed conditional probabilities for sample 136000 / 316755
# [t-SNE] Computed conditional probabilities for sample 137000 / 316755
# [t-SNE] Computed conditional probabilities for sample 138000 / 316755
# [t-SNE] Computed conditional probabilities for sample 139000 / 316755
# [t-SNE] Computed conditional probabilities for sample 140000 / 316755
# [t-SNE] Computed conditional probabilities for sample 141000 / 316755
# [t-SNE] Computed conditional probabilities for sample 142000 / 316755
# [t-SNE] Computed conditional probabilities for sample 143000 / 316755
# [t-SNE] Computed conditional probabilities for sample 144000 / 316755
# [t-SNE] Computed conditional probabilities for sample 145000 / 316755
# [t-SNE] Computed conditional probabilities for sample 146000 / 316755
# [t-SNE] Computed conditional probabilities for sample 147000 / 316755
# [t-SNE] Computed conditional probabilities for sample 148000 / 316755
# [t-SNE] Computed conditional probabilities for sample 149000 / 316755
# [t-SNE] Computed conditional probabilities for sample 150000 / 316755
# [t-SNE] Computed conditional probabilities for sample 151000 / 316755
# [t-SNE] Computed conditional probabilities for sample 152000 / 316755
# [t-SNE] Computed conditional probabilities for sample 153000 / 316755
# [t-SNE] Computed conditional probabilities for sample 154000 / 316755
# [t-SNE] Computed conditional probabilities for sample 155000 / 316755
# [t-SNE] Computed conditional probabilities for sample 156000 / 316755
# [t-SNE] Computed conditional probabilities for sample 157000 / 316755
# [t-SNE] Computed conditional probabilities for sample 158000 / 316755
# [t-SNE] Computed conditional probabilities for sample 159000 / 316755
# [t-SNE] Computed conditional probabilities for sample 160000 / 316755
# [t-SNE] Computed conditional probabilities for sample 161000 / 316755
# [t-SNE] Computed conditional probabilities for sample 162000 / 316755
# [t-SNE] Computed conditional probabilities for sample 163000 / 316755
# [t-SNE] Computed conditional probabilities for sample 164000 / 316755
# [t-SNE] Computed conditional probabilities for sample 165000 / 316755
# [t-SNE] Computed conditional probabilities for sample 166000 / 316755
# [t-SNE] Computed conditional probabilities for sample 167000 / 316755
# [t-SNE] Computed conditional probabilities for sample 168000 / 316755
# [t-SNE] Computed conditional probabilities for sample 169000 / 316755
# [t-SNE] Computed conditional probabilities for sample 170000 / 316755
# [t-SNE] Computed conditional probabilities for sample 171000 / 316755
# [t-SNE] Computed conditional probabilities for sample 172000 / 316755
# [t-SNE] Computed conditional probabilities for sample 173000 / 316755
# [t-SNE] Computed conditional probabilities for sample 174000 / 316755
# [t-SNE] Computed conditional probabilities for sample 175000 / 316755
# [t-SNE] Computed conditional probabilities for sample 176000 / 316755
# [t-SNE] Computed conditional probabilities for sample 177000 / 316755
# [t-SNE] Computed conditional probabilities for sample 178000 / 316755
# [t-SNE] Computed conditional probabilities for sample 179000 / 316755
# [t-SNE] Computed conditional probabilities for sample 180000 / 316755
# [t-SNE] Computed conditional probabilities for sample 181000 / 316755
# [t-SNE] Computed conditional probabilities for sample 182000 / 316755
# [t-SNE] Computed conditional probabilities for sample 183000 / 316755
# [t-SNE] Computed conditional probabilities for sample 184000 / 316755
# [t-SNE] Computed conditional probabilities for sample 185000 / 316755
# [t-SNE] Computed conditional probabilities for sample 186000 / 316755
# [t-SNE] Computed conditional probabilities for sample 187000 / 316755
# [t-SNE] Computed conditional probabilities for sample 188000 / 316755
# [t-SNE] Computed conditional probabilities for sample 189000 / 316755
# [t-SNE] Computed conditional probabilities for sample 190000 / 316755
# [t-SNE] Computed conditional probabilities for sample 191000 / 316755
# [t-SNE] Computed conditional probabilities for sample 192000 / 316755
# [t-SNE] Computed conditional probabilities for sample 193000 / 316755
# [t-SNE] Computed conditional probabilities for sample 194000 / 316755
# [t-SNE] Computed conditional probabilities for sample 195000 / 316755
# [t-SNE] Computed conditional probabilities for sample 196000 / 316755
# [t-SNE] Computed conditional probabilities for sample 197000 / 316755
# [t-SNE] Computed conditional probabilities for sample 198000 / 316755
# [t-SNE] Computed conditional probabilities for sample 199000 / 316755
# [t-SNE] Computed conditional probabilities for sample 200000 / 316755
# [t-SNE] Computed conditional probabilities for sample 201000 / 316755
# [t-SNE] Computed conditional probabilities for sample 202000 / 316755
# [t-SNE] Computed conditional probabilities for sample 203000 / 316755
# [t-SNE] Computed conditional probabilities for sample 204000 / 316755
# [t-SNE] Computed conditional probabilities for sample 205000 / 316755
# [t-SNE] Computed conditional probabilities for sample 206000 / 316755
# [t-SNE] Computed conditional probabilities for sample 207000 / 316755
# [t-SNE] Computed conditional probabilities for sample 208000 / 316755
# [t-SNE] Computed conditional probabilities for sample 209000 / 316755
# [t-SNE] Computed conditional probabilities for sample 210000 / 316755
# [t-SNE] Computed conditional probabilities for sample 211000 / 316755
# [t-SNE] Computed conditional probabilities for sample 212000 / 316755
# [t-SNE] Computed conditional probabilities for sample 213000 / 316755
# [t-SNE] Computed conditional probabilities for sample 214000 / 316755
# [t-SNE] Computed conditional probabilities for sample 215000 / 316755
# [t-SNE] Computed conditional probabilities for sample 216000 / 316755
# [t-SNE] Computed conditional probabilities for sample 217000 / 316755
# [t-SNE] Computed conditional probabilities for sample 218000 / 316755
# [t-SNE] Computed conditional probabilities for sample 219000 / 316755
# [t-SNE] Computed conditional probabilities for sample 220000 / 316755
# [t-SNE] Computed conditional probabilities for sample 221000 / 316755
# [t-SNE] Computed conditional probabilities for sample 222000 / 316755
# [t-SNE] Computed conditional probabilities for sample 223000 / 316755
# [t-SNE] Computed conditional probabilities for sample 224000 / 316755
# [t-SNE] Computed conditional probabilities for sample 225000 / 316755
# [t-SNE] Computed conditional probabilities for sample 226000 / 316755
# [t-SNE] Computed conditional probabilities for sample 227000 / 316755
# [t-SNE] Computed conditional probabilities for sample 228000 / 316755
# [t-SNE] Computed conditional probabilities for sample 229000 / 316755
# [t-SNE] Computed conditional probabilities for sample 230000 / 316755
# [t-SNE] Computed conditional probabilities for sample 231000 / 316755
# [t-SNE] Computed conditional probabilities for sample 232000 / 316755
# [t-SNE] Computed conditional probabilities for sample 233000 / 316755
# [t-SNE] Computed conditional probabilities for sample 234000 / 316755
# [t-SNE] Computed conditional probabilities for sample 235000 / 316755
# [t-SNE] Computed conditional probabilities for sample 236000 / 316755
# [t-SNE] Computed conditional probabilities for sample 237000 / 316755
# [t-SNE] Computed conditional probabilities for sample 238000 / 316755
# [t-SNE] Computed conditional probabilities for sample 239000 / 316755
# [t-SNE] Computed conditional probabilities for sample 240000 / 316755
# [t-SNE] Computed conditional probabilities for sample 241000 / 316755
# [t-SNE] Computed conditional probabilities for sample 242000 / 316755
# [t-SNE] Computed conditional probabilities for sample 243000 / 316755
# [t-SNE] Computed conditional probabilities for sample 244000 / 316755
# [t-SNE] Computed conditional probabilities for sample 245000 / 316755
# [t-SNE] Computed conditional probabilities for sample 246000 / 316755
# [t-SNE] Computed conditional probabilities for sample 247000 / 316755
# [t-SNE] Computed conditional probabilities for sample 248000 / 316755
# [t-SNE] Computed conditional probabilities for sample 249000 / 316755
# [t-SNE] Computed conditional probabilities for sample 250000 / 316755
# [t-SNE] Computed conditional probabilities for sample 251000 / 316755
# [t-SNE] Computed conditional probabilities for sample 252000 / 316755
# [t-SNE] Computed conditional probabilities for sample 253000 / 316755
# [t-SNE] Computed conditional probabilities for sample 254000 / 316755
# [t-SNE] Computed conditional probabilities for sample 255000 / 316755
# [t-SNE] Computed conditional probabilities for sample 256000 / 316755
# [t-SNE] Computed conditional probabilities for sample 257000 / 316755
# [t-SNE] Computed conditional probabilities for sample 258000 / 316755
# [t-SNE] Computed conditional probabilities for sample 259000 / 316755
# [t-SNE] Computed conditional probabilities for sample 260000 / 316755
# [t-SNE] Computed conditional probabilities for sample 261000 / 316755
# [t-SNE] Computed conditional probabilities for sample 262000 / 316755
# [t-SNE] Computed conditional probabilities for sample 263000 / 316755
# [t-SNE] Computed conditional probabilities for sample 264000 / 316755
# [t-SNE] Computed conditional probabilities for sample 265000 / 316755
# [t-SNE] Computed conditional probabilities for sample 266000 / 316755
# [t-SNE] Computed conditional probabilities for sample 267000 / 316755
# [t-SNE] Computed conditional probabilities for sample 268000 / 316755
# [t-SNE] Computed conditional probabilities for sample 269000 / 316755
# [t-SNE] Computed conditional probabilities for sample 270000 / 316755
# [t-SNE] Computed conditional probabilities for sample 271000 / 316755
# [t-SNE] Computed conditional probabilities for sample 272000 / 316755
# [t-SNE] Computed conditional probabilities for sample 273000 / 316755
# [t-SNE] Computed conditional probabilities for sample 274000 / 316755
# [t-SNE] Computed conditional probabilities for sample 275000 / 316755
# [t-SNE] Computed conditional probabilities for sample 276000 / 316755
# [t-SNE] Computed conditional probabilities for sample 277000 / 316755
# [t-SNE] Computed conditional probabilities for sample 278000 / 316755
# [t-SNE] Computed conditional probabilities for sample 279000 / 316755
# [t-SNE] Computed conditional probabilities for sample 280000 / 316755
# [t-SNE] Computed conditional probabilities for sample 281000 / 316755
# [t-SNE] Computed conditional probabilities for sample 282000 / 316755
# [t-SNE] Computed conditional probabilities for sample 283000 / 316755
# [t-SNE] Computed conditional probabilities for sample 284000 / 316755
# [t-SNE] Computed conditional probabilities for sample 285000 / 316755
# [t-SNE] Computed conditional probabilities for sample 286000 / 316755
# [t-SNE] Computed conditional probabilities for sample 287000 / 316755
# [t-SNE] Computed conditional probabilities for sample 288000 / 316755
# [t-SNE] Computed conditional probabilities for sample 289000 / 316755
# [t-SNE] Computed conditional probabilities for sample 290000 / 316755
# [t-SNE] Computed conditional probabilities for sample 291000 / 316755
# [t-SNE] Computed conditional probabilities for sample 292000 / 316755
# [t-SNE] Computed conditional probabilities for sample 293000 / 316755
# [t-SNE] Computed conditional probabilities for sample 294000 / 316755
# [t-SNE] Computed conditional probabilities for sample 295000 / 316755
# [t-SNE] Computed conditional probabilities for sample 296000 / 316755
# [t-SNE] Computed conditional probabilities for sample 297000 / 316755
# [t-SNE] Computed conditional probabilities for sample 298000 / 316755
# [t-SNE] Computed conditional probabilities for sample 299000 / 316755
# [t-SNE] Computed conditional probabilities for sample 300000 / 316755
# [t-SNE] Computed conditional probabilities for sample 301000 / 316755
# [t-SNE] Computed conditional probabilities for sample 302000 / 316755
# [t-SNE] Computed conditional probabilities for sample 303000 / 316755
# [t-SNE] Computed conditional probabilities for sample 304000 / 316755
# [t-SNE] Computed conditional probabilities for sample 305000 / 316755
# [t-SNE] Computed conditional probabilities for sample 306000 / 316755
# [t-SNE] Computed conditional probabilities for sample 307000 / 316755
# [t-SNE] Computed conditional probabilities for sample 308000 / 316755
# [t-SNE] Computed conditional probabilities for sample 309000 / 316755
# [t-SNE] Computed conditional probabilities for sample 310000 / 316755
# [t-SNE] Computed conditional probabilities for sample 311000 / 316755
# [t-SNE] Computed conditional probabilities for sample 312000 / 316755
# [t-SNE] Computed conditional probabilities for sample 313000 / 316755
# [t-SNE] Computed conditional probabilities for sample 314000 / 316755
# [t-SNE] Computed conditional probabilities for sample 315000 / 316755
# [t-SNE] Computed conditional probabilities for sample 316000 / 316755
# [t-SNE] Computed conditional probabilities for sample 316755 / 316755
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Computed conditional probabilities in 2.803s
# /Users/z0h03ws/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:996: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# [t-SNE] Iteration 50: error = 146.1621094, gradient norm = 0.0008558 (50 iterations in 21.653s)
# [t-SNE] Iteration 100: error = 142.7243652, gradient norm = 0.0016430 (50 iterations in 19.512s)
# [t-SNE] Iteration 150: error = 130.8240356, gradient norm = 0.0014898 (50 iterations in 17.392s)
# [t-SNE] Iteration 200: error = 123.8704529, gradient norm = 0.0011295 (50 iterations in 16.435s)
# [t-SNE] Iteration 250: error = 119.3483353, gradient norm = 0.0010984 (50 iterations in 16.084s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 119.348335
# [t-SNE] Iteration 300: error = 7.4072609, gradient norm = 0.0007141 (50 iterations in 16.233s)
# [t-SNE] Iteration 350: error = 7.1757441, gradient norm = 0.0006255 (50 iterations in 16.164s)
# [t-SNE] Iteration 400: error = 6.8116813, gradient norm = 0.0005305 (50 iterations in 15.623s)
# [t-SNE] Iteration 450: error = 6.4881120, gradient norm = 0.0004514 (50 iterations in 15.575s)
# [t-SNE] Iteration 500: error = 6.1902261, gradient norm = 0.0003868 (50 iterations in 15.322s)
# [t-SNE] Iteration 550: error = 5.8530960, gradient norm = 0.0003364 (50 iterations in 15.520s)
# [t-SNE] Iteration 600: error = 5.6788116, gradient norm = 0.0002959 (50 iterations in 15.324s)
# [t-SNE] Iteration 650: error = 5.4626274, gradient norm = 0.0002641 (50 iterations in 15.279s)
# [t-SNE] Iteration 700: error = 5.1656351, gradient norm = 0.0002387 (50 iterations in 15.121s)
# [t-SNE] Iteration 750: error = 5.0145006, gradient norm = 0.0002166 (50 iterations in 15.339s)
# [t-SNE] Iteration 800: error = 4.8499069, gradient norm = 0.0001982 (50 iterations in 15.444s)
# [t-SNE] Iteration 850: error = 4.7265878, gradient norm = 0.0001829 (50 iterations in 15.602s)
# [t-SNE] Iteration 900: error = 4.5662813, gradient norm = 0.0001691 (50 iterations in 15.313s)
# [t-SNE] Iteration 950: error = 4.4569178, gradient norm = 0.0001573 (50 iterations in 15.593s)
# [t-SNE] Iteration 1000: error = 4.2370558, gradient norm = 0.0001474 (50 iterations in 15.518s)
# [t-SNE] Iteration 1050: error = 4.1377902, gradient norm = 0.0001388 (50 iterations in 15.635s)
# [t-SNE] Iteration 1100: error = 4.0169706, gradient norm = 0.0001306 (50 iterations in 15.719s)
# [t-SNE] Iteration 1150: error = 3.9240971, gradient norm = 0.0001238 (50 iterations in 15.726s)
# [t-SNE] Iteration 1200: error = 3.8419189, gradient norm = 0.0001176 (50 iterations in 15.685s)
# [t-SNE] Iteration 1250: error = 3.7705841, gradient norm = 0.0001120 (50 iterations in 15.860s)
# [t-SNE] Iteration 1300: error = 3.6535587, gradient norm = 0.0001064 (50 iterations in 15.594s)
# [t-SNE] Iteration 1350: error = 3.5857515, gradient norm = 0.0001023 (50 iterations in 15.815s)
# [t-SNE] Iteration 1400: error = 3.5006256, gradient norm = 0.0000980 (50 iterations in 15.735s)
# [t-SNE] Iteration 1450: error = 3.3865082, gradient norm = 0.0000939 (50 iterations in 15.738s)
# [t-SNE] Iteration 1500: error = 3.3061757, gradient norm = 0.0000906 (50 iterations in 15.718s)
# [t-SNE] Iteration 1550: error = 3.2460587, gradient norm = 0.0000870 (50 iterations in 15.942s)
# [t-SNE] Iteration 1600: error = 3.1557627, gradient norm = 0.0000837 (50 iterations in 15.615s)
# [t-SNE] Iteration 1650: error = 3.0812542, gradient norm = 0.0000809 (50 iterations in 15.855s)
# [t-SNE] Iteration 1700: error = 3.0235531, gradient norm = 0.0000778 (50 iterations in 15.862s)
# [t-SNE] Iteration 1750: error = 2.9885740, gradient norm = 0.0000752 (50 iterations in 16.085s)
# [t-SNE] Iteration 1800: error = 2.9388168, gradient norm = 0.0000732 (50 iterations in 16.318s)
# [t-SNE] Iteration 1850: error = 2.8696630, gradient norm = 0.0000707 (50 iterations in 15.520s)
# [t-SNE] Iteration 1900: error = 2.8206811, gradient norm = 0.0000691 (50 iterations in 16.410s)
# [t-SNE] Iteration 1950: error = 2.7392178, gradient norm = 0.0000669 (50 iterations in 16.404s)
# [t-SNE] Iteration 2000: error = 2.6881771, gradient norm = 0.0000654 (50 iterations in 16.474s)
# [t-SNE] Iteration 2050: error = 2.6238174, gradient norm = 0.0000637 (50 iterations in 16.256s)
# [t-SNE] Iteration 2100: error = 2.5806365, gradient norm = 0.0000611 (50 iterations in 15.975s)
# [t-SNE] Iteration 2150: error = 2.5485969, gradient norm = 0.0000607 (50 iterations in 16.572s)
# [t-SNE] Iteration 2200: error = 2.5036952, gradient norm = 0.0000598 (50 iterations in 15.912s)
# [t-SNE] Iteration 2250: error = 2.4747639, gradient norm = 0.0000574 (50 iterations in 16.360s)
# [t-SNE] Iteration 2300: error = 2.4132557, gradient norm = 0.0000561 (50 iterations in 16.069s)
# [t-SNE] Iteration 2350: error = 2.3794398, gradient norm = 0.0000550 (50 iterations in 15.878s)
# [t-SNE] Iteration 2400: error = 2.2985425, gradient norm = 0.0000545 (50 iterations in 16.331s)
# [t-SNE] Iteration 2450: error = 2.2701831, gradient norm = 0.0000520 (50 iterations in 16.120s)
# [t-SNE] Iteration 2500: error = 2.2306573, gradient norm = 0.0000513 (50 iterations in 16.094s)
# [t-SNE] KL divergence after 2500 iterations: 2.230657
# ['output_tsne/tsne_lda_cloud_2.pkl']

# %%
# find the most probable topic for each recipe category
_lda_keys = []
for i in range(_topics.shape[0]):
    _lda_keys += _topics[i].argmax(),

# show topics and their top words
topic_summaries = []
topic_word = lda_model.topic_word_  # get the topic words
vocab = cvectorizer.get_feature_names()
for i, topic_dist in enumerate(topic_word):
    topic_words = np.array(vocab)[np.argsort(topic_dist)][:-(n_top_words+1):-1]
    topic_summaries.append(' '.join(topic_words))
    
# 40 colors
colormap = np.array([
    "#144c73", "#1f77b4", "#aec7e8", "#d6e2f3", "#c15a00", "#ff7f0e", "#ffbb78", "#ffe2c5",
    "#1c641c","#2ca02c", "#98df8a", "#cdefc6", "#951b1c", "#d62728", "#ff9896", "#ffe3e3",
    "#6e4196", "#9467bd", "#c5b0d5", "#eae2f0", "#5a3730", "#8c564b", "#c49c94","#dfcac5",
    "#d638a6", "#e377c2","#f0b6de", "#f7b6d2", "#fce4ee", "#595959", "#7f7f7f",
    "#c7c7c7","#ededed","#7c7c16", "#bcbd22", "#dbdb8d","#ededc7", "#0f7f8a",
    "#17becf", "#9edae5", "#daf1f5"
  ])

# plot
title = "[Recipe Topics] t-SNE visualization of LDA model trained on {} names, {} topics, thresholding at {} topic probability, {} iter ({} datapoints and top {} words)".format(X_topics.shape[0], n_topics, threshold, n_iter, num_example, n_top_words)

plot_lda = bp.figure(min_width=2000, min_height=1300, title=title,
                       tools="pan,wheel_zoom,box_zoom,reset,hover,save",
                       x_axis_type=None, y_axis_type=None, min_border=1)
source = bp.ColumnDataSource(data={'x':tsne_lda[:, 0],'y':tsne_lda[:, 1], 'color':colormap[_lda_keys][:num_example],
                                  "content": recipe_names[:num_example],
                                  "topic_key": _lda_keys[:num_example]})
plot_lda.scatter(x='x', y='y',color='color',source=source)

topic_coord = np.empty((X_topics.shape[1], 2)) * np.nan
for topic_num in _lda_keys:
    if not np.isnan(topic_coord).any():
        break
    topic_coord[topic_num] = tsne_lda[_lda_keys.index(topic_num)]

# plot crucial words
for i in range(X_topics.shape[1]):
    plot_lda.text(topic_coord[i, 0], topic_coord[i, 1], [topic_summaries[i]])

# hover tools
hover = plot_lda.select(dict(type=HoverTool))
hover.tooltips = {"content": "@content - topic: @topic_key"}

save(plot_lda, out_dir + '/NEW_20_recipe_names_final_tsne_2_lda_viz_{}_{}_{}_{}_{}_{}.html'.format(
    X_topics.shape[0], n_topics, threshold, n_iter, num_example, n_top_words))
# Out:
# /var/folders/l6/8hfvh79x19x6b73t634zs2c00000gq/T/ipykernel_50909/3613390621.py:49: UserWarning: save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN
#   save(plot_lda, out_dir + '/NEW_20_recipe_names_final_tsne_2_lda_viz_{}_{}_{}_{}_{}_{}.html'.format(
# /var/folders/l6/8hfvh79x19x6b73t634zs2c00000gq/T/ipykernel_50909/3613390621.py:49: UserWarning: save() called but no title was supplied and output_file(...) was never called, using default title 'Bokeh Plot'
#   save(plot_lda, out_dir + '/NEW_20_recipe_names_final_tsne_2_lda_viz_{}_{}_{}_{}_{}_{}.html'.format(
# '/Users/z0h03ws/Downloads/Food-Recipe-CNN/output_tsne/NEW_20_recipe_names_final_tsne_2_lda_viz_316755_40_0_500_316755_4.html'

# %%
# from IPython.display import Image
# PATH = "/Users/Muriz/Desktop/download-1.png"
# Image(filename = PATH, width='100%', height=140)

# %%
# Image(filename = '/Users/Muriz/Desktop/download.png', width='100%', height=140)
